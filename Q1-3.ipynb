# %%
#Q1 start

import numpy as np
import cv2
import os

# Define the path to the folder containing the images
notebook_path = os.path.abspath("Q1.ipynb")
path_to_folder = os.path.join(os.path.dirname(notebook_path), "data/ORL_dataset/")

# Initialize an empty numpy array to store the image data
data = np.empty((400, 2576))

# Initialize an empty list to store the gender labels
labels = []

# Loop through each image in the folder
for i, filename in enumerate(os.listdir(path_to_folder)):
    # Read the image using OpenCV
    img = cv2.imread(os.path.join(path_to_folder, filename), cv2.IMREAD_GRAYSCALE)
    
    # Flatten the image into a 1D numpy array
    img_flat = img.flatten()
    
    # Add the flattened image data to the data matrix
    data[i, :] = img_flat
    
    # Determine the gender label based on the filename (assuming filenames are formatted as "f01-01.png" or "m01-01.png")
    if filename.startswith('1_'):
        labels.append(0)
    elif filename.startswith('8_'):
        labels.append(0)
    elif filename.startswith('10_'):
        labels.append(0)
    elif filename.startswith('32_'):
        labels.append(0)
    else:
        labels.append(1)

# Convert the labels list to a numpy array and reshape to a column vector
labels = np.array(labels).reshape((400, 1))

# Concatenate the labels column to the data matrix
data_with_labels = np.concatenate((data, labels), axis=1)

print('Data shape:', data.shape)
print('Labels shape:', labels.shape)
print('Data with Labels', data_with_labels.shape)
# Out:
# Data shape: (400, 2576)
# Labels shape: (400, 1)
# Data with Labels (400, 2577)

# %%
import statsmodels.api as sm

# Split the data matrix into predictor variables (pixels) and response variable (gender label)
X = data_with_labels[:, :-1]
y = data_with_labels[:, -1]

# Add a constant term to the predictor variables to fit an intercept in the regression model
X = sm.add_constant(X)

# Fit a linear regression model
model = sm.OLS(y, X).fit()

# Print the summary statistics for the model
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Sun, 12 Mar 2023   Prob (F-statistic):                nan
# Time:                        18:24:08   Log-Likelihood:                 12603.
# No. Observations:                 400   AIC:                        -2.441e+04
# Df Residuals:                       0   BIC:                        -2.281e+04
# Df Model:                         399
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.245e-06        inf          0        nan         nan         nan
# x1             0.0001        inf          0        nan         nan         nan
# x2             0.0001        inf          0        nan         nan         nan
# x3             0.0001        inf          0        nan         nan         nan
# x4             0.0001        inf          0        nan         nan         nan
# x5           6.92e-05        inf          0        nan         nan         nan
# x6          1.067e-05        inf          0        nan         nan         nan
# x7         -9.023e-05        inf         -0        nan         nan         nan
# x8         -9.828e-05        inf         -0        nan         nan         nan
# x9         -7.247e-05        inf         -0        nan         nan         nan
# x10         4.966e-05        inf          0        nan         nan         nan
# x11           -0.0001        inf         -0        nan         nan         nan
# x12           -0.0001        inf         -0        nan         nan         nan
# x13        -7.705e-05        inf         -0        nan         nan         nan
# x14        -7.381e-05        inf         -0        nan         nan         nan
# x15         4.428e-05        inf          0        nan         nan         nan
# x16        -1.894e-05        inf         -0        nan         nan         nan
# x17         9.129e-05        inf          0        nan         nan         nan
# x18            0.0001        inf          0        nan         nan         nan
# x19         3.617e-05        inf          0        nan         nan         nan
# x20            0.0001        inf          0        nan         nan         nan
# x21         7.662e-06        inf          0        nan         nan         nan
# x22        -1.274e-05        inf         -0        nan         nan         nan
# x23         9.112e-05        inf          0        nan         nan         nan
# x24            0.0002        inf          0        nan         nan         nan
# x25         4.259e-05        inf          0        nan         nan         nan
# x26        -8.632e-05        inf         -0        nan         nan         nan
# x27           -0.0002        inf         -0        nan         nan         nan
# x28         3.092e-05        inf          0        nan         nan         nan
# x29         3.053e-05        inf          0        nan         nan         nan
# x30        -5.822e-05        inf         -0        nan         nan         nan
# x31         2.756e-06        inf          0        nan         nan         nan
# x32        -4.399e-05        inf         -0        nan         nan         nan
# x33        -7.031e-05        inf         -0        nan         nan         nan
# x34           -0.0001        inf         -0        nan         nan         nan
# x35           -0.0003        inf         -0        nan         nan         nan
# x36           -0.0002        inf         -0        nan         nan         nan
# x37        -9.664e-05        inf         -0        nan         nan         nan
# x38           -0.0002        inf         -0        nan         nan         nan
# x39           -0.0002        inf         -0        nan         nan         nan
# x40           -0.0001        inf         -0        nan         nan         nan
# x41           -0.0001        inf         -0        nan         nan         nan
# x42           -0.0002        inf         -0        nan         nan         nan
# x43           -0.0002        inf         -0        nan         nan         nan
# x44           -0.0002        inf         -0        nan         nan         nan
# x45           -0.0002        inf         -0        nan         nan         nan
# x46           -0.0002        inf         -0        nan         nan         nan
# x47            0.0001        inf          0        nan         nan         nan
# x48            0.0002        inf          0        nan         nan         nan
# x49            0.0002        inf          0        nan         nan         nan
# x50            0.0001        inf          0        nan         nan         nan
# x51        -4.087e-05        inf         -0        nan         nan         nan
# x52        -3.663e-05        inf         -0        nan         nan         nan
# x53        -4.875e-05        inf         -0        nan         nan         nan
# x54           -0.0001        inf         -0        nan         nan         nan
# x55         -9.18e-05        inf         -0        nan         nan         nan
# x56         -8.23e-05        inf         -0        nan         nan         nan
# x57           -0.0002        inf         -0        nan         nan         nan
# x58           -0.0002        inf         -0        nan         nan         nan
# x59        -7.518e-05        inf         -0        nan         nan         nan
# x60         -2.28e-05        inf         -0        nan         nan         nan
# x61        -3.639e-05        inf         -0        nan         nan         nan
# x62         4.376e-05        inf          0        nan         nan         nan
# x63        -4.828e-05        inf         -0        nan         nan         nan
# x64        -9.112e-05        inf         -0        nan         nan         nan
# x65        -5.657e-05        inf         -0        nan         nan         nan
# x66         7.463e-05        inf          0        nan         nan         nan
# x67         4.829e-05        inf          0        nan         nan         nan
# x68          4.39e-05        inf          0        nan         nan         nan
# x69         5.118e-05        inf          0        nan         nan         nan
# x70        -3.149e-05        inf         -0        nan         nan         nan
# x71           -0.0001        inf         -0        nan         nan         nan
# x72         2.128e-05        inf          0        nan         nan         nan
# x73          8.65e-05        inf          0        nan         nan         nan
# x74            0.0001        inf          0        nan         nan         nan
# x75         9.356e-05        inf          0        nan         nan         nan
# x76        -1.924e-05        inf         -0        nan         nan         nan
# x77        -2.966e-05        inf         -0        nan         nan         nan
# x78        -8.129e-06        inf         -0        nan         nan         nan
# x79            0.0001        inf          0        nan         nan         nan
# x80            0.0001        inf          0        nan         nan         nan
# x81           -0.0001        inf         -0        nan         nan         nan
# x82           -0.0002        inf         -0        nan         nan         nan
# x83        -4.607e-05        inf         -0        nan         nan         nan
# x84        -3.476e-05        inf         -0        nan         nan         nan
# x85        -1.816e-06        inf         -0        nan         nan         nan
# x86         -9.16e-05        inf         -0        nan         nan         nan
# x87           -0.0001        inf         -0        nan         nan         nan
# x88           -0.0001        inf         -0        nan         nan         nan
# x89           -0.0002        inf         -0        nan         nan         nan
# x90           -0.0002        inf         -0        nan         nan         nan
# x91           -0.0002        inf         -0        nan         nan         nan
# x92           -0.0002        inf         -0        nan         nan         nan
# x93            0.0001        inf          0        nan         nan         nan
# x94            0.0002        inf          0        nan         nan         nan
# x95            0.0002        inf          0        nan         nan         nan
# x96        -5.313e-05        inf         -0        nan         nan         nan
# x97        -5.688e-05        inf         -0        nan         nan         nan
# x98         8.725e-06        inf          0        nan         nan         nan
# x99        -6.994e-05        inf         -0        nan         nan         nan
# x100       -8.493e-05        inf         -0        nan         nan         nan
# x101       -6.436e-05        inf         -0        nan         nan         nan
# x102          -0.0001        inf         -0        nan         nan         nan
# x103          -0.0002        inf         -0        nan         nan         nan
# x104          -0.0002        inf         -0        nan         nan         nan
# x105        1.848e-05        inf          0        nan         nan         nan
# x106           0.0001        inf          0        nan         nan         nan
# x107       -1.868e-05        inf         -0        nan         nan         nan
# x108        3.231e-05        inf          0        nan         nan         nan
# x109       -2.377e-05        inf         -0        nan         nan         nan
# x110       -7.606e-05        inf         -0        nan         nan         nan
# x111          -0.0001        inf         -0        nan         nan         nan
# x112          -0.0001        inf         -0        nan         nan         nan
# x113       -4.379e-05        inf         -0        nan         nan         nan
# x114        6.763e-05        inf          0        nan         nan         nan
# x115           0.0001        inf          0        nan         nan         nan
# x116         7.18e-05        inf          0        nan         nan         nan
# x117        1.981e-05        inf          0        nan         nan         nan
# x118         6.46e-05        inf          0        nan         nan         nan
# x119       -9.857e-06        inf         -0        nan         nan         nan
# x120        5.768e-05        inf          0        nan         nan         nan
# x121        5.302e-05        inf          0        nan         nan         nan
# x122       -4.874e-05        inf         -0        nan         nan         nan
# x123       -9.929e-05        inf         -0        nan         nan         nan
# x124          -0.0001        inf         -0        nan         nan         nan
# x125       -5.858e-05        inf         -0        nan         nan         nan
# x126           0.0001        inf          0        nan         nan         nan
# x127        4.526e-05        inf          0        nan         nan         nan
# x128          -0.0002        inf         -0        nan         nan         nan
# x129       -2.745e-05        inf         -0        nan         nan         nan
# x130          -0.0001        inf         -0        nan         nan         nan
# x131       -2.568e-05        inf         -0        nan         nan         nan
# x132        -4.62e-05        inf         -0        nan         nan         nan
# x133          -0.0001        inf         -0        nan         nan         nan
# x134          -0.0001        inf         -0        nan         nan         nan
# x135       -6.641e-05        inf         -0        nan         nan         nan
# x136          -0.0002        inf         -0        nan         nan         nan
# x137          -0.0002        inf         -0        nan         nan         nan
# x138          -0.0002        inf         -0        nan         nan         nan
# x139        8.565e-05        inf          0        nan         nan         nan
# x140           0.0002        inf          0        nan         nan         nan
# x141        2.475e-05        inf          0        nan         nan         nan
# x142       -7.319e-05        inf         -0        nan         nan         nan
# x143        4.129e-05        inf          0        nan         nan         nan
# x144        4.762e-05        inf          0        nan         nan         nan
# x145       -8.228e-06        inf         -0        nan         nan         nan
# x146       -2.886e-06        inf         -0        nan         nan         nan
# x147        3.654e-05        inf          0        nan         nan         nan
# x148       -9.504e-05        inf         -0        nan         nan         nan
# x149       -4.034e-05        inf         -0        nan         nan         nan
# x150       -1.506e-05        inf         -0        nan         nan         nan
# x151          -0.0002        inf         -0        nan         nan         nan
# x152        1.784e-05        inf          0        nan         nan         nan
# x153           0.0002        inf          0        nan         nan         nan
# x154           0.0002        inf          0        nan         nan         nan
# x155           0.0002        inf          0        nan         nan         nan
# x156           0.0002        inf          0        nan         nan         nan
# x157           0.0002        inf          0        nan         nan         nan
# x158        5.401e-05        inf          0        nan         nan         nan
# x159        8.781e-05        inf          0        nan         nan         nan
# x160         8.88e-05        inf          0        nan         nan         nan
# x161           0.0001        inf          0        nan         nan         nan
# x162         4.49e-05        inf          0        nan         nan         nan
# x163        4.529e-05        inf          0        nan         nan         nan
# x164       -4.104e-05        inf         -0        nan         nan         nan
# x165          -0.0001        inf         -0        nan         nan         nan
# x166        3.297e-05        inf          0        nan         nan         nan
# x167         2.59e-05        inf          0        nan         nan         nan
# x168          -0.0001        inf         -0        nan         nan         nan
# x169          -0.0001        inf         -0        nan         nan         nan
# x170       -4.811e-05        inf         -0        nan         nan         nan
# x171        -9.54e-05        inf         -0        nan         nan         nan
# x172          -0.0001        inf         -0        nan         nan         nan
# x173       -3.938e-05        inf         -0        nan         nan         nan
# x174       -1.499e-05        inf         -0        nan         nan         nan
# x175        8.031e-05        inf          0        nan         nan         nan
# x176        7.545e-05        inf          0        nan         nan         nan
# x177       -7.322e-05        inf         -0        nan         nan         nan
# x178          -0.0002        inf         -0        nan         nan         nan
# x179          -0.0002        inf         -0        nan         nan         nan
# x180          -0.0002        inf         -0        nan         nan         nan
# x181       -8.577e-05        inf         -0        nan         nan         nan
# x182       -2.937e-05        inf         -0        nan         nan         nan
# x183          -0.0002        inf         -0        nan         nan         nan
# x184          -0.0002        inf         -0        nan         nan         nan
# x185           0.0001        inf          0        nan         nan         nan
# x186           0.0001        inf          0        nan         nan         nan
# x187        3.864e-06        inf          0        nan         nan         nan
# x188       -2.629e-05        inf         -0        nan         nan         nan
# x189        8.829e-05        inf          0        nan         nan         nan
# x190           0.0001        inf          0        nan         nan         nan
# x191        9.061e-05        inf          0        nan         nan         nan
# x192        1.229e-05        inf          0        nan         nan         nan
# x193       -3.531e-07        inf         -0        nan         nan         nan
# x194          -0.0001        inf         -0        nan         nan         nan
# x195         6.47e-05        inf          0        nan         nan         nan
# x196        1.075e-05        inf          0        nan         nan         nan
# x197        1.215e-05        inf          0        nan         nan         nan
# x198         1.32e-05        inf          0        nan         nan         nan
# x199           0.0001        inf          0        nan         nan         nan
# x200           0.0002        inf          0        nan         nan         nan
# x201           0.0003        inf          0        nan         nan         nan
# x202           0.0003        inf          0        nan         nan         nan
# x203           0.0003        inf          0        nan         nan         nan
# x204           0.0002        inf          0        nan         nan         nan
# x205        1.704e-05        inf          0        nan         nan         nan
# x206       -6.875e-05        inf         -0        nan         nan         nan
# x207       -7.708e-05        inf         -0        nan         nan         nan
# x208       -4.347e-06        inf         -0        nan         nan         nan
# x209        4.848e-05        inf          0        nan         nan         nan
# x210        -3.44e-05        inf         -0        nan         nan         nan
# x211       -9.706e-05        inf         -0        nan         nan         nan
# x212           0.0001        inf          0        nan         nan         nan
# x213          -0.0001        inf         -0        nan         nan         nan
# x214          -0.0001        inf         -0        nan         nan         nan
# x215          -0.0002        inf         -0        nan         nan         nan
# x216       -8.909e-05        inf         -0        nan         nan         nan
# x217       -4.595e-05        inf         -0        nan         nan         nan
# x218          -0.0001        inf         -0        nan         nan         nan
# x219          -0.0001        inf         -0        nan         nan         nan
# x220        1.602e-05        inf          0        nan         nan         nan
# x221        -8.51e-06        inf         -0        nan         nan         nan
# x222        4.358e-05        inf          0        nan         nan         nan
# x223          -0.0002        inf         -0        nan         nan         nan
# x224          -0.0001        inf         -0        nan         nan         nan
# x225          -0.0001        inf         -0        nan         nan         nan
# x226        -8.18e-05        inf         -0        nan         nan         nan
# x227       -5.749e-05        inf         -0        nan         nan         nan
# x228       -9.592e-05        inf         -0        nan         nan         nan
# x229          -0.0001        inf         -0        nan         nan         nan
# x230          -0.0001        inf         -0        nan         nan         nan
# x231        9.215e-05        inf          0        nan         nan         nan
# x232        4.464e-05        inf          0        nan         nan         nan
# x233       -3.793e-06        inf         -0        nan         nan         nan
# x234           0.0001        inf          0        nan         nan         nan
# x235           0.0001        inf          0        nan         nan         nan
# x236           0.0001        inf          0        nan         nan         nan
# x237        8.769e-05        inf          0        nan         nan         nan
# x238       -8.386e-05        inf         -0        nan         nan         nan
# x239        -2.18e-05        inf         -0        nan         nan         nan
# x240        9.023e-05        inf          0        nan         nan         nan
# x241        1.473e-05        inf          0        nan         nan         nan
# x242           0.0001        inf          0        nan         nan         nan
# x243           0.0002        inf          0        nan         nan         nan
# x244       -6.279e-05        inf         -0        nan         nan         nan
# x245       -8.652e-05        inf         -0        nan         nan         nan
# x246           0.0002        inf          0        nan         nan         nan
# x247           0.0002        inf          0        nan         nan         nan
# x248           0.0001        inf          0        nan         nan         nan
# x249        8.589e-05        inf          0        nan         nan         nan
# x250         2.82e-05        inf          0        nan         nan         nan
# x251       -3.219e-05        inf         -0        nan         nan         nan
# x252         -1.1e-05        inf         -0        nan         nan         nan
# x253       -7.943e-05        inf         -0        nan         nan         nan
# x254        -1.72e-05        inf         -0        nan         nan         nan
# x255       -1.838e-06        inf         -0        nan         nan         nan
# x256        2.853e-05        inf          0        nan         nan         nan
# x257       -2.278e-05        inf         -0        nan         nan         nan
# x258        2.356e-05        inf          0        nan         nan         nan
# x259       -5.315e-05        inf         -0        nan         nan         nan
# x260       -6.586e-05        inf         -0        nan         nan         nan
# x261        5.408e-05        inf          0        nan         nan         nan
# x262        -6.83e-05        inf         -0        nan         nan         nan
# x263       -5.276e-05        inf         -0        nan         nan         nan
# x264       -2.178e-05        inf         -0        nan         nan         nan
# x265        4.929e-07        inf          0        nan         nan         nan
# x266        2.823e-05        inf          0        nan         nan         nan
# x267       -9.743e-05        inf         -0        nan         nan         nan
# x268          -0.0002        inf         -0        nan         nan         nan
# x269          -0.0002        inf         -0        nan         nan         nan
# x270       -6.816e-05        inf         -0        nan         nan         nan
# x271       -6.615e-05        inf         -0        nan         nan         nan
# x272        -8.35e-07        inf         -0        nan         nan         nan
# x273        5.294e-05        inf          0        nan         nan         nan
# x274       -6.175e-05        inf         -0        nan         nan         nan
# x275          -0.0002        inf         -0        nan         nan         nan
# x276          -0.0001        inf         -0        nan         nan         nan
# x277        2.771e-05        inf          0        nan         nan         nan
# x278        5.189e-05        inf          0        nan         nan         nan
# x279           0.0001        inf          0        nan         nan         nan
# x280           0.0002        inf          0        nan         nan         nan
# x281        1.229e-05        inf          0        nan         nan         nan
# x282        5.747e-05        inf          0        nan         nan         nan
# x283        2.794e-05        inf          0        nan         nan         nan
# x284        1.384e-05        inf          0        nan         nan         nan
# x285           0.0001        inf          0        nan         nan         nan
# x286        6.523e-05        inf          0        nan         nan         nan
# x287        1.526e-05        inf          0        nan         nan         nan
# x288           0.0001        inf          0        nan         nan         nan
# x289       -2.179e-05        inf         -0        nan         nan         nan
# x290        6.757e-06        inf          0        nan         nan         nan
# x291       -3.314e-05        inf         -0        nan         nan         nan
# x292        3.556e-05        inf          0        nan         nan         nan
# x293        -3.82e-06        inf         -0        nan         nan         nan
# x294       -9.707e-05        inf         -0        nan         nan         nan
# x295       -9.857e-05        inf         -0        nan         nan         nan
# x296       -7.973e-05        inf         -0        nan         nan         nan
# x297       -8.342e-05        inf         -0        nan         nan         nan
# x298       -6.149e-05        inf         -0        nan         nan         nan
# x299       -9.169e-05        inf         -0        nan         nan         nan
# x300          -0.0002        inf         -0        nan         nan         nan
# x301       -8.705e-05        inf         -0        nan         nan         nan
# x302        9.492e-05        inf          0        nan         nan         nan
# x303           0.0002        inf          0        nan         nan         nan
# x304           0.0001        inf          0        nan         nan         nan
# x305        6.959e-05        inf          0        nan         nan         nan
# x306         4.59e-05        inf          0        nan         nan         nan
# x307           0.0001        inf          0        nan         nan         nan
# x308       -4.682e-05        inf         -0        nan         nan         nan
# x309          -0.0001        inf         -0        nan         nan         nan
# x310       -1.498e-05        inf         -0        nan         nan         nan
# x311       -5.502e-05        inf         -0        nan         nan         nan
# x312        9.349e-05        inf          0        nan         nan         nan
# x313           0.0001        inf          0        nan         nan         nan
# x314       -7.355e-05        inf         -0        nan         nan         nan
# x315          -0.0001        inf         -0        nan         nan         nan
# x316       -7.385e-05        inf         -0        nan         nan         nan
# x317       -2.052e-05        inf         -0        nan         nan         nan
# x318       -4.134e-05        inf         -0        nan         nan         nan
# x319         4.62e-05        inf          0        nan         nan         nan
# x320        8.085e-05        inf          0        nan         nan         nan
# x321        -3.22e-05        inf         -0        nan         nan         nan
# x322          -0.0002        inf         -0        nan         nan         nan
# x323           0.0002        inf          0        nan         nan         nan
# x324         6.67e-05        inf          0        nan         nan         nan
# x325           0.0003        inf          0        nan         nan         nan
# x326           0.0001        inf          0        nan         nan         nan
# x327       -7.815e-05        inf         -0        nan         nan         nan
# x328           0.0002        inf          0        nan         nan         nan
# x329       -6.177e-06        inf         -0        nan         nan         nan
# x330           0.0001        inf          0        nan         nan         nan
# x331        7.844e-05        inf          0        nan         nan         nan
# x332           0.0001        inf          0        nan         nan         nan
# x333       -6.471e-06        inf         -0        nan         nan         nan
# x334       -2.932e-06        inf         -0        nan         nan         nan
# x335        5.634e-05        inf          0        nan         nan         nan
# x336        6.476e-05        inf          0        nan         nan         nan
# x337        5.748e-05        inf          0        nan         nan         nan
# x338         9.14e-05        inf          0        nan         nan         nan
# x339       -6.628e-05        inf         -0        nan         nan         nan
# x340          -0.0001        inf         -0        nan         nan         nan
# x341          -0.0002        inf         -0        nan         nan         nan
# x342          -0.0002        inf         -0        nan         nan         nan
# x343          -0.0002        inf         -0        nan         nan         nan
# x344       -8.507e-05        inf         -0        nan         nan         nan
# x345        1.152e-05        inf          0        nan         nan         nan
# x346       -5.649e-05        inf         -0        nan         nan         nan
# x347          -0.0001        inf         -0        nan         nan         nan
# x348        6.814e-05        inf          0        nan         nan         nan
# x349           0.0002        inf          0        nan         nan         nan
# x350           0.0002        inf          0        nan         nan         nan
# x351        6.318e-05        inf          0        nan         nan         nan
# x352       -3.902e-05        inf         -0        nan         nan         nan
# x353        3.104e-05        inf          0        nan         nan         nan
# x354       -7.577e-05        inf         -0        nan         nan         nan
# x355       -5.834e-05        inf         -0        nan         nan         nan
# x356         8.61e-05        inf          0        nan         nan         nan
# x357        2.538e-05        inf          0        nan         nan         nan
# x358       -3.201e-05        inf         -0        nan         nan         nan
# x359        -1.45e-05        inf         -0        nan         nan         nan
# x360        5.408e-05        inf          0        nan         nan         nan
# x361        9.267e-05        inf          0        nan         nan         nan
# x362        8.765e-06        inf          0        nan         nan         nan
# x363        8.383e-05        inf          0        nan         nan         nan
# x364           0.0001        inf          0        nan         nan         nan
# x365        7.584e-05        inf          0        nan         nan         nan
# x366           0.0001        inf          0        nan         nan         nan
# x367           0.0001        inf          0        nan         nan         nan
# x368          -0.0001        inf         -0        nan         nan         nan
# x369       -1.534e-05        inf         -0        nan         nan         nan
# x370        8.545e-05        inf          0        nan         nan         nan
# x371           0.0003        inf          0        nan         nan         nan
# x372       -1.247e-06        inf         -0        nan         nan         nan
# x373        -1.98e-05        inf         -0        nan         nan         nan
# x374       -1.193e-05        inf         -0        nan         nan         nan
# x375           0.0001        inf          0        nan         nan         nan
# x376        2.252e-05        inf          0        nan         nan         nan
# x377        1.264e-05        inf          0        nan         nan         nan
# x378           0.0002        inf          0        nan         nan         nan
# x379           0.0001        inf          0        nan         nan         nan
# x380           0.0001        inf          0        nan         nan         nan
# x381           0.0002        inf          0        nan         nan         nan
# x382           0.0001        inf          0        nan         nan         nan
# x383        4.538e-05        inf          0        nan         nan         nan
# x384       -1.499e-05        inf         -0        nan         nan         nan
# x385       -4.655e-05        inf         -0        nan         nan         nan
# x386       -6.013e-05        inf         -0        nan         nan         nan
# x387       -2.597e-05        inf         -0        nan         nan         nan
# x388        -4.89e-05        inf         -0        nan         nan         nan
# x389       -4.729e-05        inf         -0        nan         nan         nan
# x390       -3.406e-05        inf         -0        nan         nan         nan
# x391       -7.848e-05        inf         -0        nan         nan         nan
# x392       -2.244e-06        inf         -0        nan         nan         nan
# x393          -0.0001        inf         -0        nan         nan         nan
# x394          -0.0001        inf         -0        nan         nan         nan
# x395       -7.441e-05        inf         -0        nan         nan         nan
# x396           0.0001        inf          0        nan         nan         nan
# x397           0.0001        inf          0        nan         nan         nan
# x398        9.378e-05        inf          0        nan         nan         nan
# x399        2.648e-05        inf          0        nan         nan         nan
# x400       -3.972e-05        inf         -0        nan         nan         nan
# x401         9.31e-06        inf          0        nan         nan         nan
# x402        3.602e-05        inf          0        nan         nan         nan
# x403        2.861e-05        inf          0        nan         nan         nan
# x404           0.0002        inf          0        nan         nan         nan
# x405        -7.89e-05        inf         -0        nan         nan         nan
# x406       -2.072e-05        inf         -0        nan         nan         nan
# x407         4.44e-05        inf          0        nan         nan         nan
# x408        2.455e-06        inf          0        nan         nan         nan
# x409       -8.976e-05        inf         -0        nan         nan         nan
# x410           0.0001        inf          0        nan         nan         nan
# x411        7.326e-05        inf          0        nan         nan         nan
# x412        3.875e-05        inf          0        nan         nan         nan
# x413           0.0001        inf          0        nan         nan         nan
# x414        9.746e-05        inf          0        nan         nan         nan
# x415        1.763e-05        inf          0        nan         nan         nan
# x416           0.0002        inf          0        nan         nan         nan
# x417           0.0001        inf          0        nan         nan         nan
# x418        7.548e-05        inf          0        nan         nan         nan
# x419          -0.0002        inf         -0        nan         nan         nan
# x420       -3.115e-05        inf         -0        nan         nan         nan
# x421        4.173e-05        inf          0        nan         nan         nan
# x422       -5.546e-05        inf         -0        nan         nan         nan
# x423        9.193e-05        inf          0        nan         nan         nan
# x424           0.0001        inf          0        nan         nan         nan
# x425           0.0001        inf          0        nan         nan         nan
# x426           0.0002        inf          0        nan         nan         nan
# x427           0.0001        inf          0        nan         nan         nan
# x428           0.0001        inf          0        nan         nan         nan
# x429       -7.983e-05        inf         -0        nan         nan         nan
# x430       -6.689e-05        inf         -0        nan         nan         nan
# x431       -1.176e-05        inf         -0        nan         nan         nan
# x432         2.88e-05        inf          0        nan         nan         nan
# x433          2.3e-05        inf          0        nan         nan         nan
# x434        3.465e-05        inf          0        nan         nan         nan
# x435         2.69e-05        inf          0        nan         nan         nan
# x436        4.772e-05        inf          0        nan         nan         nan
# x437         -6.8e-06        inf         -0        nan         nan         nan
# x438       -2.689e-05        inf         -0        nan         nan         nan
# x439          -0.0001        inf         -0        nan         nan         nan
# x440          -0.0003        inf         -0        nan         nan         nan
# x441          -0.0003        inf         -0        nan         nan         nan
# x442          -0.0002        inf         -0        nan         nan         nan
# x443       -2.077e-05        inf         -0        nan         nan         nan
# x444        8.745e-05        inf          0        nan         nan         nan
# x445           0.0002        inf          0        nan         nan         nan
# x446           0.0001        inf          0        nan         nan         nan
# x447           0.0001        inf          0        nan         nan         nan
# x448           0.0001        inf          0        nan         nan         nan
# x449       -4.735e-05        inf         -0        nan         nan         nan
# x450        6.436e-05        inf          0        nan         nan         nan
# x451           0.0001        inf          0        nan         nan         nan
# x452       -1.846e-05        inf         -0        nan         nan         nan
# x453       -5.422e-05        inf         -0        nan         nan         nan
# x454        8.278e-05        inf          0        nan         nan         nan
# x455       -6.663e-05        inf         -0        nan         nan         nan
# x456       -3.711e-05        inf         -0        nan         nan         nan
# x457        9.437e-05        inf          0        nan         nan         nan
# x458        7.421e-06        inf          0        nan         nan         nan
# x459           0.0001        inf          0        nan         nan         nan
# x460           0.0002        inf          0        nan         nan         nan
# x461           0.0001        inf          0        nan         nan         nan
# x462           0.0001        inf          0        nan         nan         nan
# x463        3.163e-05        inf          0        nan         nan         nan
# x464          -0.0001        inf         -0        nan         nan         nan
# x465          -0.0002        inf         -0        nan         nan         nan
# x466        9.727e-05        inf          0        nan         nan         nan
# x467       -2.623e-05        inf         -0        nan         nan         nan
# x468       -2.295e-05        inf         -0        nan         nan         nan
# x469       -1.374e-05        inf         -0        nan         nan         nan
# x470        1.847e-05        inf          0        nan         nan         nan
# x471           0.0001        inf          0        nan         nan         nan
# x472           0.0001        inf          0        nan         nan         nan
# x473           0.0001        inf          0        nan         nan         nan
# x474        6.537e-05        inf          0        nan         nan         nan
# x475       -3.827e-06        inf         -0        nan         nan         nan
# x476        -3.68e-05        inf         -0        nan         nan         nan
# x477        1.419e-06        inf          0        nan         nan         nan
# x478       -1.219e-05        inf         -0        nan         nan         nan
# x479       -6.246e-05        inf         -0        nan         nan         nan
# x480        7.275e-06        inf          0        nan         nan         nan
# x481        7.092e-05        inf          0        nan         nan         nan
# x482        7.315e-05        inf          0        nan         nan         nan
# x483        3.323e-05        inf          0        nan         nan         nan
# x484        4.869e-05        inf          0        nan         nan         nan
# x485       -3.442e-05        inf         -0        nan         nan         nan
# x486          -0.0002        inf         -0        nan         nan         nan
# x487          -0.0002        inf         -0        nan         nan         nan
# x488          -0.0002        inf         -0        nan         nan         nan
# x489        7.274e-06        inf          0        nan         nan         nan
# x490        5.689e-05        inf          0        nan         nan         nan
# x491           0.0002        inf          0        nan         nan         nan
# x492           0.0002        inf          0        nan         nan         nan
# x493           0.0001        inf          0        nan         nan         nan
# x494           0.0002        inf          0        nan         nan         nan
# x495           0.0002        inf          0        nan         nan         nan
# x496        2.294e-05        inf          0        nan         nan         nan
# x497        6.646e-05        inf          0        nan         nan         nan
# x498           0.0001        inf          0        nan         nan         nan
# x499        -9.39e-05        inf         -0        nan         nan         nan
# x500        3.359e-05        inf          0        nan         nan         nan
# x501        9.101e-06        inf          0        nan         nan         nan
# x502       -3.707e-05        inf         -0        nan         nan         nan
# x503        1.751e-05        inf          0        nan         nan         nan
# x504       -8.519e-05        inf         -0        nan         nan         nan
# x505       -1.464e-05        inf         -0        nan         nan         nan
# x506           0.0001        inf          0        nan         nan         nan
# x507           0.0001        inf          0        nan         nan         nan
# x508           0.0001        inf          0        nan         nan         nan
# x509          -0.0001        inf         -0        nan         nan         nan
# x510          -0.0003        inf         -0        nan         nan         nan
# x511        6.801e-05        inf          0        nan         nan         nan
# x512        5.247e-06        inf          0        nan         nan         nan
# x513        2.384e-05        inf          0        nan         nan         nan
# x514        5.255e-05        inf          0        nan         nan         nan
# x515           0.0001        inf          0        nan         nan         nan
# x516           0.0002        inf          0        nan         nan         nan
# x517           0.0002        inf          0        nan         nan         nan
# x518        7.883e-05        inf          0        nan         nan         nan
# x519         1.15e-05        inf          0        nan         nan         nan
# x520          -0.0001        inf         -0        nan         nan         nan
# x521       -8.601e-05        inf         -0        nan         nan         nan
# x522        -4.04e-05        inf         -0        nan         nan         nan
# x523        2.005e-05        inf          0        nan         nan         nan
# x524       -2.708e-05        inf         -0        nan         nan         nan
# x525        2.674e-06        inf          0        nan         nan         nan
# x526       -4.592e-05        inf         -0        nan         nan         nan
# x527          -0.0001        inf         -0        nan         nan         nan
# x528       -5.959e-05        inf         -0        nan         nan         nan
# x529        4.146e-05        inf          0        nan         nan         nan
# x530           0.0001        inf          0        nan         nan         nan
# x531        2.904e-05        inf          0        nan         nan         nan
# x532          -0.0001        inf         -0        nan         nan         nan
# x533          -0.0002        inf         -0        nan         nan         nan
# x534       -7.822e-05        inf         -0        nan         nan         nan
# x535       -1.747e-05        inf         -0        nan         nan         nan
# x536         5.41e-05        inf          0        nan         nan         nan
# x537         7.31e-05        inf          0        nan         nan         nan
# x538        6.118e-05        inf          0        nan         nan         nan
# x539           0.0001        inf          0        nan         nan         nan
# x540           0.0001        inf          0        nan         nan         nan
# x541           0.0001        inf          0        nan         nan         nan
# x542           0.0001        inf          0        nan         nan         nan
# x543        6.326e-05        inf          0        nan         nan         nan
# x544        6.171e-05        inf          0        nan         nan         nan
# x545          -0.0001        inf         -0        nan         nan         nan
# x546       -9.073e-05        inf         -0        nan         nan         nan
# x547       -4.207e-05        inf         -0        nan         nan         nan
# x548       -5.022e-05        inf         -0        nan         nan         nan
# x549        4.434e-05        inf          0        nan         nan         nan
# x550        8.215e-05        inf          0        nan         nan         nan
# x551       -2.965e-05        inf         -0        nan         nan         nan
# x552        7.552e-05        inf          0        nan         nan         nan
# x553           0.0002        inf          0        nan         nan         nan
# x554       -4.764e-05        inf         -0        nan         nan         nan
# x555          -0.0003        inf         -0        nan         nan         nan
# x556       -7.978e-05        inf         -0        nan         nan         nan
# x557        1.022e-05        inf          0        nan         nan         nan
# x558       -8.437e-05        inf         -0        nan         nan         nan
# x559          -0.0001        inf         -0        nan         nan         nan
# x560       -1.383e-05        inf         -0        nan         nan         nan
# x561           0.0001        inf          0        nan         nan         nan
# x562        9.849e-05        inf          0        nan         nan         nan
# x563        3.346e-05        inf          0        nan         nan         nan
# x564       -3.932e-05        inf         -0        nan         nan         nan
# x565          -0.0001        inf         -0        nan         nan         nan
# x566       -9.928e-06        inf         -0        nan         nan         nan
# x567        5.317e-05        inf          0        nan         nan         nan
# x568           0.0002        inf          0        nan         nan         nan
# x569        2.898e-05        inf          0        nan         nan         nan
# x570       -4.734e-05        inf         -0        nan         nan         nan
# x571          -0.0002        inf         -0        nan         nan         nan
# x572          -0.0001        inf         -0        nan         nan         nan
# x573          -0.0001        inf         -0        nan         nan         nan
# x574          -0.0001        inf         -0        nan         nan         nan
# x575        7.397e-05        inf          0        nan         nan         nan
# x576           0.0001        inf          0        nan         nan         nan
# x577        8.509e-05        inf          0        nan         nan         nan
# x578       -9.479e-06        inf         -0        nan         nan         nan
# x579       -5.385e-05        inf         -0        nan         nan         nan
# x580       -6.669e-05        inf         -0        nan         nan         nan
# x581       -6.597e-05        inf         -0        nan         nan         nan
# x582        3.703e-05        inf          0        nan         nan         nan
# x583        1.974e-05        inf          0        nan         nan         nan
# x584        6.941e-05        inf          0        nan         nan         nan
# x585           0.0002        inf          0        nan         nan         nan
# x586        3.697e-05        inf          0        nan         nan         nan
# x587         -7.3e-05        inf         -0        nan         nan         nan
# x588        2.085e-05        inf          0        nan         nan         nan
# x589       -3.896e-05        inf         -0        nan         nan         nan
# x590       -9.639e-05        inf         -0        nan         nan         nan
# x591          -0.0002        inf         -0        nan         nan         nan
# x592          -0.0002        inf         -0        nan         nan         nan
# ...
# x2383      -2.759e-05        inf         -0        nan         nan         nan
# x2384       7.044e-05        inf          0        nan         nan         nan
# x2385          0.0001        inf          0        nan         nan         nan
# x2386       4.107e-05        inf          0        nan         nan         nan
# x2387       1.546e-05        inf          0        nan         nan         nan
# x2388         -0.0001        inf         -0        nan         nan         nan
# x2389       9.761e-05        inf          0        nan         nan         nan
# x2390       4.624e-05        inf          0        nan         nan         nan
# x2391      -1.037e-05        inf         -0        nan         nan         nan
# x2392      -1.513e-05        inf         -0        nan         nan         nan
# x2393          0.0003        inf          0        nan         nan         nan
# x2394       4.615e-05        inf          0        nan         nan         nan
# x2395       -7.42e-05        inf         -0        nan         nan         nan
# x2396       5.769e-05        inf          0        nan         nan         nan
# x2397      -8.651e-05        inf         -0        nan         nan         nan
# x2398          0.0001        inf          0        nan         nan         nan
# x2399       7.368e-05        inf          0        nan         nan         nan
# x2400          0.0002        inf          0        nan         nan         nan
# x2401       6.789e-05        inf          0        nan         nan         nan
# x2402       7.267e-05        inf          0        nan         nan         nan
# x2403       3.598e-05        inf          0        nan         nan         nan
# x2404       1.994e-05        inf          0        nan         nan         nan
# x2405      -4.652e-06        inf         -0        nan         nan         nan
# x2406       3.948e-05        inf          0        nan         nan         nan
# x2407      -2.591e-05        inf         -0        nan         nan         nan
# x2408       7.507e-05        inf          0        nan         nan         nan
# x2409       5.654e-05        inf          0        nan         nan         nan
# x2410       4.611e-05        inf          0        nan         nan         nan
# x2411          0.0002        inf          0        nan         nan         nan
# x2412       6.697e-05        inf          0        nan         nan         nan
# x2413       6.543e-06        inf          0        nan         nan         nan
# x2414       5.813e-05        inf          0        nan         nan         nan
# x2415        9.81e-05        inf          0        nan         nan         nan
# x2416      -7.665e-06        inf         -0        nan         nan         nan
# x2417       4.271e-05        inf          0        nan         nan         nan
# x2418          0.0001        inf          0        nan         nan         nan
# x2419       8.399e-05        inf          0        nan         nan         nan
# x2420          0.0002        inf          0        nan         nan         nan
# x2421          0.0002        inf          0        nan         nan         nan
# x2422          0.0001        inf          0        nan         nan         nan
# x2423          0.0001        inf          0        nan         nan         nan
# x2424       5.387e-05        inf          0        nan         nan         nan
# x2425      -4.093e-05        inf         -0        nan         nan         nan
# x2426         -0.0002        inf         -0        nan         nan         nan
# x2427          0.0001        inf          0        nan         nan         nan
# x2428       3.424e-05        inf          0        nan         nan         nan
# x2429      -5.255e-05        inf         -0        nan         nan         nan
# x2430         -0.0001        inf         -0        nan         nan         nan
# x2431      -1.364e-05        inf         -0        nan         nan         nan
# x2432          0.0001        inf          0        nan         nan         nan
# x2433       8.548e-05        inf          0        nan         nan         nan
# x2434      -4.623e-05        inf         -0        nan         nan         nan
# x2435      -3.602e-05        inf         -0        nan         nan         nan
# x2436      -3.329e-06        inf         -0        nan         nan         nan
# x2437      -2.279e-05        inf         -0        nan         nan         nan
# x2438      -8.946e-05        inf         -0        nan         nan         nan
# x2439          0.0003        inf          0        nan         nan         nan
# x2440          0.0002        inf          0        nan         nan         nan
# x2441       6.541e-06        inf          0        nan         nan         nan
# x2442          0.0001        inf          0        nan         nan         nan
# x2443       5.502e-05        inf          0        nan         nan         nan
# x2444          0.0002        inf          0        nan         nan         nan
# x2445       1.276e-05        inf          0        nan         nan         nan
# x2446          0.0002        inf          0        nan         nan         nan
# x2447       9.686e-05        inf          0        nan         nan         nan
# x2448      -6.634e-05        inf         -0        nan         nan         nan
# x2449       1.191e-05        inf          0        nan         nan         nan
# x2450      -2.556e-05        inf         -0        nan         nan         nan
# x2451      -6.341e-06        inf         -0        nan         nan         nan
# x2452       6.098e-06        inf          0        nan         nan         nan
# x2453      -2.171e-06        inf         -0        nan         nan         nan
# x2454       3.044e-05        inf          0        nan         nan         nan
# x2455      -6.418e-05        inf         -0        nan         nan         nan
# x2456      -8.139e-05        inf         -0        nan         nan         nan
# x2457      -3.078e-05        inf         -0        nan         nan         nan
# x2458       6.747e-05        inf          0        nan         nan         nan
# x2459      -1.628e-05        inf         -0        nan         nan         nan
# x2460      -1.083e-05        inf         -0        nan         nan         nan
# x2461       9.939e-06        inf          0        nan         nan         nan
# x2462       2.382e-05        inf          0        nan         nan         nan
# x2463       6.444e-05        inf          0        nan         nan         nan
# x2464          0.0001        inf          0        nan         nan         nan
# x2465      -7.415e-06        inf         -0        nan         nan         nan
# x2466      -1.975e-05        inf         -0        nan         nan         nan
# x2467          0.0001        inf          0        nan         nan         nan
# x2468       8.305e-05        inf          0        nan         nan         nan
# x2469      -5.226e-06        inf         -0        nan         nan         nan
# x2470      -9.879e-05        inf         -0        nan         nan         nan
# x2471         -0.0002        inf         -0        nan         nan         nan
# x2472         -0.0001        inf         -0        nan         nan         nan
# x2473          0.0002        inf          0        nan         nan         nan
# x2474      -1.565e-05        inf         -0        nan         nan         nan
# x2475      -7.709e-05        inf         -0        nan         nan         nan
# x2476         -0.0001        inf         -0        nan         nan         nan
# x2477      -7.527e-05        inf         -0        nan         nan         nan
# x2478          0.0001        inf          0        nan         nan         nan
# x2479       5.496e-05        inf          0        nan         nan         nan
# x2480       3.239e-05        inf          0        nan         nan         nan
# x2481      -1.025e-05        inf         -0        nan         nan         nan
# x2482         -0.0001        inf         -0        nan         nan         nan
# x2483      -9.166e-05        inf         -0        nan         nan         nan
# x2484      -6.336e-05        inf         -0        nan         nan         nan
# x2485          0.0002        inf          0        nan         nan         nan
# x2486          0.0003        inf          0        nan         nan         nan
# x2487       2.442e-05        inf          0        nan         nan         nan
# x2488       1.594e-05        inf          0        nan         nan         nan
# x2489          0.0001        inf          0        nan         nan         nan
# x2490      -8.416e-05        inf         -0        nan         nan         nan
# x2491      -2.114e-05        inf         -0        nan         nan         nan
# x2492      -7.337e-05        inf         -0        nan         nan         nan
# x2493       5.118e-05        inf          0        nan         nan         nan
# x2494      -6.626e-05        inf         -0        nan         nan         nan
# x2495       -4.13e-05        inf         -0        nan         nan         nan
# x2496      -3.656e-05        inf         -0        nan         nan         nan
# x2497      -6.186e-05        inf         -0        nan         nan         nan
# x2498      -5.385e-05        inf         -0        nan         nan         nan
# x2499      -8.461e-05        inf         -0        nan         nan         nan
# x2500         -0.0001        inf         -0        nan         nan         nan
# x2501      -2.288e-05        inf         -0        nan         nan         nan
# x2502      -7.878e-05        inf         -0        nan         nan         nan
# x2503         -0.0002        inf         -0        nan         nan         nan
# x2504      -3.407e-05        inf         -0        nan         nan         nan
# x2505      -1.129e-05        inf         -0        nan         nan         nan
# x2506       -9.27e-05        inf         -0        nan         nan         nan
# x2507      -5.774e-05        inf         -0        nan         nan         nan
# x2508      -1.007e-05        inf         -0        nan         nan         nan
# x2509       6.114e-08        inf          0        nan         nan         nan
# x2510       4.713e-05        inf          0        nan         nan         nan
# x2511      -3.272e-05        inf         -0        nan         nan         nan
# x2512         -0.0002        inf         -0        nan         nan         nan
# x2513      -6.059e-05        inf         -0        nan         nan         nan
# x2514      -5.767e-05        inf         -0        nan         nan         nan
# x2515         -0.0001        inf         -0        nan         nan         nan
# x2516         -0.0002        inf         -0        nan         nan         nan
# x2517         -0.0002        inf         -0        nan         nan         nan
# x2518      -5.429e-05        inf         -0        nan         nan         nan
# x2519          0.0002        inf          0        nan         nan         nan
# x2520      -1.241e-05        inf         -0        nan         nan         nan
# x2521       1.164e-05        inf          0        nan         nan         nan
# x2522       2.746e-05        inf          0        nan         nan         nan
# x2523         -0.0002        inf         -0        nan         nan         nan
# x2524       3.755e-05        inf          0        nan         nan         nan
# x2525       2.337e-05        inf          0        nan         nan         nan
# x2526      -3.548e-05        inf         -0        nan         nan         nan
# x2527          0.0001        inf          0        nan         nan         nan
# x2528         -0.0002        inf         -0        nan         nan         nan
# x2529         -0.0001        inf         -0        nan         nan         nan
# x2530       2.804e-05        inf          0        nan         nan         nan
# x2531          0.0002        inf          0        nan         nan         nan
# x2532       8.614e-05        inf          0        nan         nan         nan
# x2533       1.195e-05        inf          0        nan         nan         nan
# x2534          0.0002        inf          0        nan         nan         nan
# x2535          0.0002        inf          0        nan         nan         nan
# x2536       9.567e-06        inf          0        nan         nan         nan
# x2537       2.948e-05        inf          0        nan         nan         nan
# x2538      -8.401e-05        inf         -0        nan         nan         nan
# x2539       5.672e-05        inf          0        nan         nan         nan
# x2540         -0.0002        inf         -0        nan         nan         nan
# x2541        -6.3e-05        inf         -0        nan         nan         nan
# x2542      -5.015e-05        inf         -0        nan         nan         nan
# x2543         -0.0001        inf         -0        nan         nan         nan
# x2544      -6.553e-05        inf         -0        nan         nan         nan
# x2545      -5.769e-05        inf         -0        nan         nan         nan
# x2546         -0.0002        inf         -0        nan         nan         nan
# x2547         -0.0002        inf         -0        nan         nan         nan
# x2548         -0.0002        inf         -0        nan         nan         nan
# x2549         -0.0002        inf         -0        nan         nan         nan
# x2550       -2.56e-05        inf         -0        nan         nan         nan
# x2551       6.485e-05        inf          0        nan         nan         nan
# x2552       1.681e-05        inf          0        nan         nan         nan
# x2553      -4.155e-05        inf         -0        nan         nan         nan
# x2554       2.108e-05        inf          0        nan         nan         nan
# x2555        7.85e-05        inf          0        nan         nan         nan
# x2556       6.548e-05        inf          0        nan         nan         nan
# x2557       -6.74e-05        inf         -0        nan         nan         nan
# x2558      -8.913e-05        inf         -0        nan         nan         nan
# x2559      -7.044e-05        inf         -0        nan         nan         nan
# x2560      -3.541e-06        inf         -0        nan         nan         nan
# x2561         -0.0001        inf         -0        nan         nan         nan
# x2562         -0.0001        inf         -0        nan         nan         nan
# x2563      -4.144e-05        inf         -0        nan         nan         nan
# x2564      -8.259e-05        inf         -0        nan         nan         nan
# x2565          0.0001        inf          0        nan         nan         nan
# x2566      -8.394e-05        inf         -0        nan         nan         nan
# x2567       8.195e-05        inf          0        nan         nan         nan
# x2568          0.0001        inf          0        nan         nan         nan
# x2569         -0.0001        inf         -0        nan         nan         nan
# x2570      -8.916e-06        inf         -0        nan         nan         nan
# x2571       9.237e-05        inf          0        nan         nan         nan
# x2572      -8.094e-05        inf         -0        nan         nan         nan
# x2573       6.487e-05        inf          0        nan         nan         nan
# x2574      -5.685e-08        inf         -0        nan         nan         nan
# x2575         -0.0001        inf         -0        nan         nan         nan
# x2576      -3.043e-05        inf         -0        nan         nan         nan
# ==============================================================================
# Omnibus:                        6.573   Durbin-Watson:                   0.802
# Prob(Omnibus):                  0.037   Jarque-Bera (JB):                6.536
# Skew:                          -0.259   Prob(JB):                       0.0381
# Kurtosis:                       3.352   Cond. No.                         635.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import SequentialFeatureSelector

# %%
X = data_with_labels[:, :-1]
Y = data_with_labels[:, -1]

model = LinearRegression()
model.fit(X, Y)

print("R-squared:", model.score(X, Y))
# Out:
# R-squared: 1.0

# %%
sfs = SequentialFeatureSelector(model, n_features_to_select=10, direction='forward', scoring='r2', cv=5)
sfs.fit(X, Y)

important_pixels = sfs.get_support(indices=True)
print("Important pixels:", important_pixels)

# %%
#Q1 end
canvas = np.zeros((46, 56))

for idx in important_pixels:
    row = idx // 56
    col = idx % 56
    canvas[row][col] = 255

cv2.imshow("Important Pixels", canvas)
cv2.waitKey(0)

# %%
#Q2 start

import pandas as pd
import numpy as np
import os
from sklearn.linear_model import LinearRegression

# Load the volcano dataset
notebook_path = os.path.abspath("Q2.ipynb")
data_file = os.path.join(os.path.dirname(notebook_path), "Volcano.csv")

volcano = pd.read_csv(data_file, header=None)

# Set the grid coordinates
x1 = np.arange(1, 88)
x2 = np.arange(1, 62)

# Initialize the starting point
current_point = np.array([87, 1])

# Set the domain size for each regression model
domain_size = 5

# Iterate until convergence
while True:
    # Get the current coordinates
    i = current_point[0] - 1
    j = current_point[1] - 1
    
    # Extract the domain for regression
    i_start = int(max(i - domain_size, 0))
    i_end = int(min(i + domain_size, 86))
    j_start = int(max(j - domain_size, 0))
    j_end = int(min(j + domain_size, 60))
    X1, X2 = np.meshgrid(x1[i_start:i_end+1], x2[j_start:j_end+1])
    Y = volcano.values[j_start:j_end+1, i_start:i_end+1].ravel()
    
    # Fit the regression model
    model = LinearRegression()
    X = np.column_stack((X1.ravel(), X2.ravel()))
    model.fit(X, Y)
    
    # Find the direction of improvement
    gradient = model.coef_
    direction = np.sign(gradient)
    
    # Update the current point
    new_point = current_point + direction
    if np.all(new_point == current_point):
        # Converged to a local maximum
        break
    else:
        current_point = new_point

# Print the final result
print("The highest point is:", tuple(current_point))

#Q2 end

# %%
#Q3 start
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression
import statsmodels.api as sm

# Generate data
X, y = make_regression(n_samples=50000, n_features=2, noise=10)

# Add intercept to X
X = sm.add_constant(X)

# Fit linear regression model
model = sm.OLS(y, X).fit()

# Print model summary
print(model.summary())

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression

# Generate data
X, y = make_regression(n_samples=50000, n_features=2, noise=10)

# Add intercept to X
X = np.c_[np.ones(X.shape[0]), X]

# Define learning rate and number of iterations
learning_rate = 0.01
n_iterations = 1000

# Initialize coefficients
beta = np.zeros(X.shape[1])

# Define error function and gradient function
def error(X, y, beta):
    return np.mean((y - X @ beta)**2)

def gradient(X, y, beta):
    return -2*np.mean((y - X @ beta)*X.T, axis=1)

# Perform gradient descent
errors = []
betas = [beta]
for i in range(n_iterations):
    beta = beta - learning_rate * gradient(X, y, beta)
    errors.append(error(X, y, beta))
    betas.append(beta)

# Print coefficients
print("Coefficients:", beta)
print("Regression package:", model.params)
print("Gradient descent:", beta)

# %%
import matplotlib.pyplot as plt

# Plot errors
plt.plot(errors)
plt.title("Evolution of error during gradient descent")
plt.xlabel("Iteration")
plt.ylabel("Mean squared error")
plt.show()

# Plot searching path
betas = np.array(betas)
plt.plot(betas[:,1], betas[:,2], 'bo-')
plt.title("Searching path in the domain of the error function")
plt.xlabel("beta1")
plt.ylabel("beta2")
plt.show()

#Q3 end
